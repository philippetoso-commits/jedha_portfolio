# %%
# %pip install roboflow
from roboflow import Roboflow

rf = Roboflow(api_key='nTDu19uHBvg49TaTsirp')
project = rf.workspace('roboflow-universe-projects').project('license-plate-recognition-rxg4e')
dataset = project.version(4).download('yolov8')
print('✅ Dataset téléchargé !')
# Out:
# Collecting roboflow
#   Using cached roboflow-1.2.13-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (2026.1.4)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (12.1.0)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Using cached pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /home/phili/datascience/.venv/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pi-heif<2 (from roboflow)
#   Using cached pi_heif-1.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/phili/datascience/.venv/lib/python3.12/site-packages (from requests->roboflow) (3.4.4)
# Using cached roboflow-1.2.13-py3-none-any.whl (91 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# Using cached pi_heif-1.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
# Using cached pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.90
#     Uninstalling opencv-python-headless-4.13.0.90:━━━━━━━━━━━━━━━━ 3/6 [opencv-python-headless]
#       Successfully uninstalled opencv-python-headless-4.13.0.90 3/6 [opencv-python-headless]
#   Attempting uninstall: idna╺━━━━━━━━━━━━━━━━━━━ 3/6 [opencv-python-headless]
#     Found existing installation: idna 3.11m━━━━━━━━━━━━━━━━━━━ 3/6 [opencv-python-headless]
#     Uninstalling idna-3.11:m╺━━━━━━━━━━━━━━━━━━━ 3/6 [opencv-python-headless]
#       Successfully uninstalled idna-3.1190m━━━━━━━━━━━━━━━━━━━ 3/6 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [roboflow]4/6 [idna]thon-headless]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# vllm 0.15.0 requires opencv-python-headless>=4.13.0, but you have opencv-python-headless 4.10.0.84 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.2.0 pillow-avif-plugin-1.5.5 roboflow-1.2.13
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /home/phili/datascience/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in License-Plate-Recognition-4 to yolov8:: 100%|██████████| 974784/974784 [00:29<00:00, 33059.32it/s]
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [00:06<00:00, 7576.61it/s]
# ✅ Dataset téléchargé !

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/mnt/c/DEV/jedha/fullstack_wsl/PROJETS/PROJET_FINAL/2_IMMAT_PLAQUES/YOLO8-n/ROBOFLOW_universe/License-Plate-Recognition-4/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='LP_roboflow',
    patience=20,
    save=True,
    plots=True
)

print("✅ Entraînement terminé !")
